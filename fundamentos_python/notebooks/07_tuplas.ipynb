# %%
punto = ("Arequipa", 12.445, -77.123)
type(punto)
# Out:
# tuple

# %%
punto[0] = "Lima"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 punto[0] = "Lima"
#
# TypeError: 'tuple' object does not support item assignment

# %%
punto[1] = 999.99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 punto[1] = 999.99
#
# TypeError: 'tuple' object does not support item assignment

# %%
vacia = ()
type(vacia)
# Out:
# tuple

# %%
tupla_1 = (4, )
type(tupla_1)
# Out:
# tuple

# %%
punto = ("Arequipa", 12.445, -77.123, "Arequipa", "Arequipa")

punto.count("Arequipa")
# Out:
# 3

# %%
punto.index("Arequipa")
# Out:
# 0

# %%
punto.index(-77.123)
# Out:
# 2
