# %%
venta = {
    "id": "V-101",
    "region": "Lima",
    "cantidad": 100,
    "precio": 205.5
}
venta
# Out:
# {'id': 'V-101', 'region': 'Lima', 'cantidad': 100, 'precio': 205.5}

# %% [markdown]
# ### Index

# %%
venta["region"]
# Out:
# 'Lima'

# %%
venta["precio"]
# Out:
# 205.5

# %%
venta["region"] = "Arequipa"
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 100, 'precio': 205.5}

# %%
venta["region"]
# Out:
# 'Arequipa'

# %%
venta["descuento"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 venta["descuento"]
#
# KeyError: 'descuento'

# %%
venta.get("descuento", 0)
# Out:
# 0

# %%
venta.get("moneda", "USD")
# Out:
# 'USD'

# %%
venta["moneda"] = "PEN"

# %%
venta.get("moneda", "USD")
# Out:
# 'PEN'

# %%
venta
# Out:
# {'id': 'V-101',
#  'region': 'Arequipa',
#  'cantidad': 100,
#  'precio': 205.5,
#  'moneda': 'PEN'}

# %%
del venta["moneda"]
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 100, 'precio': 205.5}

# %%
"moneda" in venta
# Out:
# False

# %%
"cantidad" in venta
# Out:
# True

# %% [markdown]
# ### Llaves / valores / items

# %%
list(venta.keys())
# Out:
# ['id', 'region', 'cantidad', 'precio']

# %%
list(venta.values())
# Out:
# ['V-101', 'Arequipa', 100, 205.5]

# %%
list(venta.items())
# Out:
# [('id', 'V-101'), ('region', 'Arequipa'), ('cantidad', 100), ('precio', 205.5)]

# %% [markdown]
# ### Actualizar y anidar diccionarios

# %%
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 100, 'precio': 205.5}

# %%
# venta["cantidad"] = 500
# venta["precio"] = 1000

venta.update({"cantidad": 500, "precio": 1000})
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 500, 'precio': 1000}

# %%
# venta["precio"] = 5000  ### ESTO HARIA UN NOVATO
venta.setdefault("descuento", 1000)
venta.setdefault("precio", 5000)
venta
# Out:
# {'id': 'V-101',
#  'region': 'Arequipa',
#  'cantidad': 500,
#  'precio': 1000,
#  'descuento': 1000}
