# %%
mi_nombre = "Marcell"

print("Me llamo:", mi_nombre)
# Out:
# Me llamo: Marcell

# %%
print(f"Me llamo: {mi_nombre}")
# Out:
# Me llamo: Marcell

# %%
cliente = "Ana Torres"
total = 6000.555555

print("Cliente:", cliente, "|" , "Total:", total)
print(f"Cliente: {cliente} | Total: {total}")
print(f"Cliente: {cliente} | Total: {total * 2}")
print(f"Cliente: {cliente} | Total: {total * 2:.2f}")
# Out:
# Cliente: Ana Torres | Total: 6000.555555
# Cliente: Ana Torres | Total: 6000.555555
# Cliente: Ana Torres | Total: 12001.11111
# Cliente: Ana Torres | Total: 12001.11
