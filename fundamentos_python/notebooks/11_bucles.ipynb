# %% [markdown]
# ### BUCLE: FOR
# #### Para recorrer colecciones: Listas, tuplas, diccionarios, conjuntos, strings, etc

# %%
regiones = ["Lima", "Arequipa", "Trujillo", "Tacna"]

for region in regiones:
    print(f"Esta es la región: {region}")
# Out:
# Esta es la región: Lima
# Esta es la región: Arequipa
# Esta es la región: Trujillo
# Esta es la región: Tacna

# %%
for idx in range(5):
    print(f"Este es el índice: {idx}")
# Out:
# Este es el índice: 0
# Este es el índice: 1
# Este es el índice: 2
# Este es el índice: 3
# Este es el índice: 4

# %%
for idx in range(1, 5):
    print(f"Este es el índice: {idx}")
# Out:
# Este es el índice: 1
# Este es el índice: 2
# Este es el índice: 3
# Este es el índice: 4

# %%
for idx in range(0, 11, 2):
    print(f"Este es el índice: {idx}")
# Out:
# Este es el índice: 0
# Este es el índice: 2
# Este es el índice: 4
# Este es el índice: 6
# Este es el índice: 8
# Este es el índice: 10

# %%
ciudad = "Arequipa"

for letra in ciudad:
    print(letra)
# Out:
# A
# r
# e
# q
# u
# i
# p
# a

# %%
venta = {
    "id": "V-101",
    "region": "Lima",
    "cantidad": 100,
    "precio": 205.5
}

for key in venta:
    print(key)
# Out:
# id
# region
# cantidad
# precio

# %%
for key, value in venta.items():
    print(f"La llave es: {key} y el valor es: {value}")
# Out:
# La llave es: id y el valor es: V-101
# La llave es: region y el valor es: Lima
# La llave es: cantidad y el valor es: 100
# La llave es: precio y el valor es: 205.5

# %%
filas = ["V-100;Lima;2", "V-101;Arequipa;3", "V-102;Cuzco;4"]

for numero_fila, fila in enumerate(filas):
    print(f"La fila: {numero_fila} tiene el valor: {fila}")
# Out:
# La fila: 0 tiene el valor: V-100;Lima;2
# La fila: 1 tiene el valor: V-101;Arequipa;3
# La fila: 2 tiene el valor: V-102;Cuzco;4

# %%
columnas = ["id", "region", "cantidad"]
valores = ["V-101", "Lima", "2"]

# %%
### NO ES PYTHONISTA, NO ES UNA BUENA PRÁCTICA DE CÓDIGO LIMPIO
for idx in range(len(columnas)):
    print(f"{columnas[idx]}: {valores[idx]}")
# Out:
# id: V-101
# region: Lima
# cantidad: 2

# %%
for columna, valor in zip(columnas, valores):
    print(f"{columna}: {valor}")
# Out:
# id: V-101
# region: Lima
# cantidad: 2

# %% [markdown]
# ### BUCLE: WHILE
# #### Para condiciones (romper condiciones, reintentos, etc)

# %%
intentos = 0

while intentos < 3:
    print(f"Intento: {intentos}")
    intentos += 1
# Out:
# Intento: 0
# Intento: 1
# Intento: 2

# %%
numero = int(input("Ingrese número: "))

while numero < 10:
    print(f"El número es: {numero}")
    numero = int(input("Ingrese número: "))

print(f"El número ganador es: {numero}")
# Out:
# El número es: 1
# El número es: 2
# El número es: 3
# El número es: 4
# El número es: 5
# El número ganador es: 10

# %% [markdown]
# ### Control o flujo de ejecución

# %%
for numero in range(20):
    if numero % 2 == 0:
        continue

    print(f"Número impar: {numero}")
# Out:
# Número impar: 1
# Número impar: 3
# Número impar: 5
# Número impar: 7
# Número impar: 9
# Número impar: 11
# Número impar: 13
# Número impar: 15
# Número impar: 17
# Número impar: 19

# %%
for numero in range(20):
    if numero % 2 == 0:
        continue

    if numero >= 10:
        break

    print(f"Número impar: {numero}")

print("El bucle finalizó")
# Out:
# Número impar: 1
# Número impar: 3
# Número impar: 5
# Número impar: 7
# Número impar: 9
# El bucle finalizó

# %%
ciudades = ["Arequipa", "Puno", "Tacna", "Ayacucho", "Cuzco"]
buscar = "Tacna"

for ciudad in ciudades:
    print(f"Ciudad: {ciudad}")
    if ciudad == "Tacna":
        print("La ciudad heroica")
        break
# Out:
# Ciudad: Arequipa
# Ciudad: Puno
# Ciudad: Tacna
# La ciudad heroica
