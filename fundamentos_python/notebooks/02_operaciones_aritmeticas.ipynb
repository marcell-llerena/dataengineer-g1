# %%
numero_1 = 20
numero_2 = 10

# %%
# operador suma
numero_1 + numero_2
# Out:
# 30

# %%
# operador resta
numero_1 - numero_2
# Out:
# 10

# %%
numero_2 - numero_1
# Out:
# -10

# %%
# operador división decimal
numero_1 / numero_2
# Out:
# 2.0

# %%
# operador división entera
numero_1 // numero_2
# Out:
# 2

# %%
# operador resto
numero_2 % numero_1
# Out:
# 10

# %%
numero_1 % numero_2
# Out:
# 0

# %%
# operador de potencia
numero_1 ** 2
# Out:
# 400

# %%
numero_2 ** 2
# Out:
# 100

# %%
total = 0
print(total)

total = total + 150
print(total)
# Out:
# 0
# 150

# %%
total = 0
print(total)

total += 150
print(total)
# Out:
# 0
# 150

# %%
edad = 20
# edad = edad - 2
edad -= 2
print(edad)
# Out:
# 18

# %%
edad = 20
edad *= 2
print(edad)
# Out:
# 40
