# %%
color = "verde"

if color == "verde":
    premio = 10
elif color == "azul":
    premio = 5
else:
    premio = 0

print(premio)
# Out:
# 10

# %%
color = "rosado"

if color == "verde":
    premio = 10
elif color == "azul":
    premio = 5
elif color == "rosado":
    premio = 3.5
elif color == "negro":
    premio = 1
else:
    premio = 0

print(premio)
# Out:
# 3.5

# %%
cantidad = 1000
precio = 50

# %%
if cantidad > 0 and precio < 10:
    total = cantidad * precio
    print(total)

# %%
if cantidad > 0 or precio < 10:
    total = cantidad * precio
    print(total)
# Out:
# 50000

# %% [markdown]
# ### Expresiones condicionales

# %%
registros = []

print("Llenar registros de hoy dia...")

if registros:
    print("Procesando...")
else:
    print("Los registros están vacíos")
# Out:
# Llenar registros de hoy dia...
# Los registros están vacíos

# %%
registros = []

print("Llenar registros de hoy dia...")
registros.extend([1, 2, 3, 4, 5])

if registros:
    print("Procesando...")
else:
    print("Los registros están vacíos")
# Out:
# Llenar registros de hoy dia...
# Procesando...

# %%
### NADA PYTHONISTA, NO SE DEBERÍA PARA TENER UN CÓDIGO MÁS LIMPIO

cantidad_registros = len(registros)

if cantidad_registros > 0:
    print("Procesando...")
# Out:
# Procesando...

# %%
nombre = None

print("Leer nombre...")

if nombre:
    print(f"Entregar pedido a: {nombre}")
else:
    print("No se registró nombre")
# Out:
# Leer nombre...
# No se registró nombre

# %%
nombre = "Sebastian"

print("Leer nombre...")

if nombre:
    print(f"Entregar pedido a: {nombre}")
else:
    print("No se registró nombre")
# Out:
# Leer nombre...
# Entregar pedido a: Sebastian

# %%
nombre = ""

print("Leer nombre...")

if nombre:
    print(f"Entregar pedido a: {nombre}")
else:
    print("No se registró nombre")
# Out:
# Leer nombre...
# No se registró nombre
