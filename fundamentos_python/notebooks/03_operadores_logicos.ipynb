# %%
cantidad = 20

# %%
cantidad > 0
# Out:
# True

# %%
cantidad < 0
# Out:
# False

# %%
cantidad >= 20
# Out:
# True

# %%
cantidad <= 10
# Out:
# False

# %%
ciudad_1 = "Arequipa"
ciudad_2 = "Lima"

ciudad_1 == ciudad_2
# Out:
# False

# %%
ciudad_1 == "Arequipa"
# Out:
# True

# %%
ciudad_1 != "Arequipa"
# Out:
# False

# %%
ciudad_2 != "Arequipa"
# Out:
# True

# %%
cantidad = 20
precio = 10

cantidad > 5 and precio > 10
# Out:
# False

# %%
cantidad > 5 or precio > 10
# Out:
# True

# %%
es_valido = False
not es_valido
# Out:
# True

# %%
es_valido = True
not es_valido
# Out:
# False

# %%
identificador = None

# identificador == None
identificador is None
# Out:
# True
