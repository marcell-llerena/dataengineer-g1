# %%
regiones = ["Lima", "Cuzco", "Piura", "Loreto"]
vacia = []
mixta = ["V-1001", 2, 23.45, True, False]

# %%
regiones[0]
# Out:
# 'Lima'

# %%
regiones[-1]
# Out:
# 'Loreto'

# %%
regiones[-4]
# Out:
# 'Lima'

# %%
# regiones[1000]

# %%
regiones[0:3]
# Out:
# ['Lima', 'Cuzco', 'Piura']

# %%
len(regiones)
# Out:
# 4

# %%
len(vacia)
# Out:
# 0

# %%
len(mixta)
# Out:
# 5

# %%
"Cuzco" in regiones
# Out:
# True

# %%
"Arequipa" in regiones
# Out:
# False

# %%
# regiones.index("Arequipa")

# %%
regiones.index("Lima")
# Out:
# 0

# %%
regiones.index("Loreto")
# Out:
# 3

# %%
regiones[0] = "Arequipa"
regiones
# Out:
# ['Arequipa', 'Cuzco', 'Piura', 'Loreto']

# %%
# regiones.index("Lima")

# %%
regiones.index("Arequipa")
# Out:
# 0

# %%
ventas = [32, 1450, 890.5]

# %% [markdown]
# ### Añadir, insertar, quitar elementos de la lista

# %%
ventas.append(2100)
ventas
# Out:
# [32, 1450, 890.5, 2100]

# %%
ventas.append(5000)
ventas
# Out:
# [32, 1450, 890.5, 2100, 5000]

# %%
ventas.append([1, 3])
ventas
# Out:
# [32, 1450, 890.5, 2100, 5000, [1, 3]]

# %%
ventas.extend([4, 5])
ventas
# Out:
# [32, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.insert(0, 55)
ventas
# Out:
# [55, 32, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.insert(2, 999)
ventas
# Out:
# [55, 32, 999, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.remove(55)
ventas
# Out:
# [32, 999, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.remove([1, 3])
ventas
# Out:
# [32, 999, 1450, 890.5, 2100, 5000, 4, 5]

# %% [markdown]
# ### Ordenar

# %%
ventas
# Out:
# [32, 999, 1450, 890.5, 2100, 5000, 4, 5]

# %%
ventas.sort()
ventas
# Out:
# [4, 5, 32, 890.5, 999, 1450, 2100, 5000]

# %%
ventas.sort(reverse=True)
ventas
# Out:
# [5000, 2100, 1450, 999, 890.5, 32, 5, 4]

# %%
ventas_asc = sorted(ventas)
ventas_asc
# Out:
# [4, 5, 32, 890.5, 999, 1450, 2100, 5000]

# %%
ventas
# Out:
# [5000, 2100, 1450, 999, 890.5, 32, 5, 4]

# %% [markdown]
# ### Operaciones / agregaciones

# %%
ventas = [1, 2, 2, 2, 2, 5, 4, 3]
sum(ventas)
# Out:
# 21

# %%
min(ventas)
# Out:
# 1

# %%
max(ventas)
# Out:
# 5

# %%
len(ventas)
# Out:
# 8

# %%
ventas.pop()
# Out:
# 3

# %%
ventas
# Out:
# [1, 2, 2, 2, 2, 5, 4]

# %%
ventas.pop()
# Out:
# 4

# %%
ventas
# Out:
# [1, 2, 2, 2, 2, 5]

# %%
ventas.count(2)
# Out:
# 4
